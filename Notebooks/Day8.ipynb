# %% [markdown]
# # Day 8

# %%
import numpy as np
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
line, = ax.plot(np.random.rand(20))
ax.set_ylim(0, 1)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import matplotlib.path as path

fig, ax = plt.subplots()

data = np.random.randn(1000)
n, bins = np.histogram(data, 50)

# Get the corners of the rectangles for the histogram
left = np.array(bins[:-1])
right = np.array(bins[1:])
bottom = np.zeros(len(left))
top = bottom + n


# We need a (numrects x numsides x 2) numpy array for the path helper
# Build a compound path
genPath = np.array([[left, left, right, right], [bottom, top, top, bottom]]).T

# Get the path object
barpath = path.Path.make_compound_path_from_polys(genPath)

# Make a patch out of it
patch = patches.PathPatch(barpath)
ax.add_patch(patch)

# Update the view limits
ax.set_xlim(left[0], right[-1])
ax.set_ylim(bottom.min(), top.max())

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
ax.plot(np.random.rand(20), '-o', ms=20, lw=2, alpha=0.7, mfc='orange')
ax.grid()

# Sets figure text
fig.text(0.5, 0.95, 'Demo Figure',
         fontsize=10, color='black',
         ha='center', va='top', alpha=1)

plt.show()
